# %%
import pickle
import numpy as np

# %%
split='dev'
path = f'./ontonotes_output_{split}/{split}/last_vec.py'
np.load(path, allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /home/julia/Code/PhD/amnesic_probing/data/ontonotes_output_train/check.ipynb Cell 2' in <cell line: 3>()
#       <a href='vscode-notebook-cell://ssh-remote%2B37.120.158.216/home/julia/Code/PhD/amnesic_probing/data/ontonotes_output_train/check.ipynb#ch0000005vscode-remote?line=0'>1</a> path = './train/last_vec.npy'
# ----> <a href='vscode-notebook-cell://ssh-remote%2B37.120.158.216/home/julia/Code/PhD/amnesic_probing/data/ontonotes_output_train/check.ipynb#ch0000005vscode-remote?line=2'>3</a> np.load(path, allow_pickle=True)
#
# File ~/miniconda3/envs/nlp39/lib/python3.9/site-packages/numpy/lib/npyio.py:440, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
# ...

# %%
with open('./train/last_vec.npy', 'rb') as file:
    a  = np.load(file, allow_pickle=True)
# Out:
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# /home/julia/Code/PhD/amnesic_probing/data/ontonotes_output_train/check.ipynb Cell 3' in <cell line: 1>()
#       <a href='vscode-notebook-cell://ssh-remote%2B37.120.158.216/home/julia/Code/PhD/amnesic_probing/data/ontonotes_output_train/check.ipynb#ch0000001vscode-remote?line=0'>1</a> with open('./train/last_vec.npy', 'rb') as file:
# ----> <a href='vscode-notebook-cell://ssh-remote%2B37.120.158.216/home/julia/Code/PhD/amnesic_probing/data/ontonotes_output_train/check.ipynb#ch0000001vscode-remote?line=1'>2</a>     a  = np.load(file, allow_pickle=True)
#
# File ~/miniconda3/envs/nlp39/lib/python3.9/site-packages/numpy/lib/npyio.py:440, in load(file, mmap_mode, allow_pickle, fix_imports, encoding)
# ...

# %%
# Out:
# [['NE', 'E', 'NE', 'E', 'E'],
#  ['E', 'E', 'E', 'NE', 'E', 'NE', 'NE', 'NE', 'NE', 'E', 'NE', 'NE', 'E', 'E'],
#  ['NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E'],
#  ['NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'E'],
#  ['E',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E'],
#  ['NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'E'],
#  ['NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
# ...

# %%
# !ls
# Out:
# check.ipynb  folderlogs.log  train

# %%
a
# Out:
# [['NE', 'E', 'NE', 'E', 'E'],
#  ['E', 'E', 'E', 'NE', 'E', 'NE', 'NE', 'NE', 'NE', 'E', 'NE', 'NE', 'E', 'E'],
#  ['NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E'],
#  ['NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'E'],
#  ['E',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E'],
#  ['NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'E',
#   'E'],
#  ['NE',
#   'NE',
#   'E',
#   'E',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
#   'NE',
#   'E',
#   'NE',
#   'NE',
# ...
